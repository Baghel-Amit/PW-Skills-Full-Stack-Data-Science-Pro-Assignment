# %% [markdown]
# Q1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# We are given the recurrence relation:
#  T(n)=3T(n−1)+12n
# with the initial condition
#  T(0)=5. We need to find
#
# Step-by-step calculation:
#
# Step 1: Calculate
#
# Using the recurrence relation for  n=1:
#  T(1)=3T(0)+12×1
# Substitute the value of T(0)=5:
#
# T(1)=3×5+12=15+12=27
# Step 2: Calculate
#
# Now, using the recurrence relation for
#
# T(2)=3T(1)+12×2
# Substitute the value of T(1)=27:
# T(2)=3×27+24=81+24=105
# Final Answer:
# T(2)=105

# %% [markdown]
# Q2. Given a recurrence relation, solve it using the substitution method:
# a. T(n) = T(n-1) + c
# b. T(n) = 2T(n/2) + n
# c. T(n) = 2T(n/2) + c
# d. T(n) = T(n/2) + c

# %% [markdown]
# The substitution method involves solving a recurrence relation by guessing the solution and proving it by induction. Let's solve each of the given recurrence relations one by one using this method.
#
# a. T(n)=T(n−1)+c
# This recurrence can be solved step by step by substituting values for T(n).
#
# Substitute for T(n−1) in the recurrence: T(n)=T(n−1)+c
#
# substitute this in for T(n−1)=T(n−2)+c
#
# (substitute this in for T(n−1))
#
# T(n)=T(n−2)+c+c=T(n−2)+2c
# Continuing this for
#
# k steps:
# T(n)=T(n−k)+kc
# Base Case: When
# T(0)=T(0)+kc=T(0)+nc.
#
# Now, using the fact that
#
# T(0)=T(0) by definition:
#
#
# T(n)=T(0)+nc
# Thus, the general solution for this recurrence is:
#
#
# T(n)=T(0)+nc
# b.
#
# T(n)=2T(n/2)+n
# This is a divide-and-conquer recurrence. Let's solve it by applying the substitution method.
#
# Substitute for
#
# T(n)=2T(n/2)+n
# Substituting
#
# T(n/2)=2T(n/4)+n/2:
#
# T(n)=2(2T(n/4)+n/2)+n=4T(n/4)+n+n
# Continuing this process:
#
# T(n)=8T(n/8)+3n
#
# T(n)=16T(n/16)+4n
# After
#
# k steps, we get:
#  T(n)=2
# k
#  T(n/2
# k
#  )+kn
# Base Case: When
#
# n=1, we have
#
# T(1)=d (a constant).
#
# To find
#
# k where
#
# n/2
# k=1, solve:
#
# n/2
# k=1⟹k=log
# 2
# Substituting into the formula:
#
# T(n)=2
# log2
#  T(1)+nlog
#  n=nT(1)+nlog
# Therefore, the solution is- T(n)=O(nlogn)
#
# c. T(n)=2T(n/2)+c
# This is another divide-and-conquer recurrence, similar to part (b), but with a constant instead of a linear term.
#
# Substitute for
# T(n)=2T(n/2)+c
# Substituting
#
# T(n/2)=2T(n/4)+c:
# T(n)=2(2T(n/4)+c)+c=4T(n/4)+2c+c=4T(n/4)+3c
# Continuing this process:
#
# T(n)=8T(n/8)+7c
# Afterk steps, we get:
#
# T(n)=2k
# T(n/2k)+(2k−1)c
# Base Case: When
# n=1, we have
# T(1)=d.
# To find
# k where
# n/2k =1, solve:
# n/2k=1⟹k=log2
#
# Substituting into the formula:
# T(n)=2log2n
# T(1)+(2log2n−1)c=nT(1)+(n−1)c
# Therefore, the solution is:
#
#
# T(n)=T(n/2)+c
# This is similar to the recurrence from part (c), but the recurrence only has a constant term (no multiplication by 2).
#
# Substitute for T(n)=T(n/2)+c
# Substituting T(n/2)=T(n/4)+c:
#
# T(n)=T(n/4)+c+c=T(n/4)+2c
# Continuing this process:
#
# T(n)=T(n/8)+3c
# After k steps, we get:
#
# T(n)=T(n/2k)+kc
# Base Case: When
# n=1, we have
# T(1)=d.
#
# To find k where n/2k=1, solve:
# Substituting into the formula:
#
# T(n)=T(1)+log2
# Therefore, the solution is:
# T(n)=O(logn)

# %% [markdown]
#  Q3. Given a recurrence relation, solve it using the recursive tree approach:
# a. T(n) = 2T(n-1) +1
# b. T(n) = 2T(n/2) + n

# %% [markdown]
# The recursive tree method is a visual approach used to solve recurrence relations. This method involves expanding the recurrence step by step and representing it as a tree, where each level of the tree corresponds to a recursive call, and the total cost is the sum of costs across all levels.
#
# Let's solve each recurrence relation using this approach:
#
# T(n)=2T(n−1)+1
# This recurrence relation is of the form where each call splits into two smaller subproblems (with
#
# 1
# n−1) plus a constant cost of 1.
#
# Step 1: Expanding the recurrence
# Start with the given recurrence:
#
#
# T(n)=2T(n−1)+1
# Expand this further:
#
#
# T(n−1)=2T(n−2)+1
# Substitute this into the original recurrence:
#
# T(n)=2(2T(n−2)+1)+1=4T(n−2)+2+1
# Now, expand
#
# T(n−2):
#
# T(n−2)=2T(n−3)+1
# Substitute this into the previous expression:
#
#
# T(n)=4(2T(n−3)+1)+3=8T(n−3)+4+3
# Step 2: Identify the pattern
# By continuing this process, we can see the recurrence tree starts developing as:
#  T(n)=2k
# T(n−k)+(2k−1)
# At each level of the tree, the number of calls doubles (since 2
#
# 2T(n−k)), and the work done at each level adds up to a total of
# Step 3: Base Case
# We stop when 0
# n−k=0. So, when
# k=n, the recurrence reaches the base case:
#
# (constant)
# T(0)=c(constant)
# Thus, when
#
# k=n, we have:
#
#
# T(n)=2nT(0)+(2n−1)
# Since
#
# T(0)=c, we get:
# T(n)=2nc+(2n−1)
# Step 4: Asymptotic Complexity
# The dominant term here is 2n
#  So, the asymptotic complexity is:
# T(n)=2T(n/2)+n
# This is a standard divide-and-conquer recurrence that splits the problem into two subproblems, each of size
#
# n/2, plus a linear work cost
#
# n at each level.
#
# Step 1: Expanding the recurrence
# Start with the given recurrence:
#
# T(n)=2T(n/2)+n
# ExpandT(n/2):
#
# T(n/2)=2T(n/4)+n/2
# Substitute this into the original recurrence:
#
# T(n)=2(2T(n/4)+n/2)+n=4T(n/4)+n+n
# Now, expand (n/4):
#
#
# T(n/4)=2T(n/8)+n/4
# Substitute this into the previous expression:
#
# T(n)=4(2T(n/8)+n/4)+2n=8T(n/8)+n+2n
# Step 2: Identify the pattern
# By continuing this process, we see that at each level of recursion, the size of the subproblems is halved, and the work done at each level is proportional to
# At level
#
# k, the size of the subproblem is
#
# k×(n/2k)=n.
#
# Thus, at each level, we do
#
# n work, and there are
# log2
#
#  n levels in total (because the size of the subproblem halves at each level).
#
# Step 3: Summing the work at all levels
# At each level, the work done is
#
# n. Since there are
# log
#
#  n levels, the total work done is:
#
# Total work=n×log2
#
# Step 4: Asymptotic Complexity
# Therefore, the time complexity of this recurrence is:
#
# T(n)=O(nlogn)
